# %%
import random
import numpy as np
import scipy.stats

n_list = []
p_list = []
price = []

# %%
for i in range(1000):
    n_list.append(int(random.uniform(150, 340)))
    p_list.append(np.int64(np.random.normal(300, 200, size=n_list[i])))

# %%
for i in range(1000):
    p_list[i] = sorted(p_list[i], reverse=True)

# %%
for i in range(1000):
    try:
        price.append(p_list[i][99])
    except:
        continue

# %%
price
# Out:
# [220,
#  374,
#  367,
#  373,
#  364,
#  409,
#  268,
#  363,
#  353,
#  408,
#  346,
#  352,
#  377,
#  371,
#  382,
#  307,
#  276,
#  413,
#  378,
#  368,
#  400,
#  416,
#  406,
#  313,
#  259,
#  312,
#  339,
#  314,
#  360,
#  265,
#  246,
#  248,
#  251,
#  251,
#  350,
#  388,
#  370,
#  323,
#  426,
#  314,
#  373,
#  234,
#  385,
#  233,
#  338,
#  358,
#  238,
#  256,
#  427,
#  379,
#  279,
#  311,
#  407,
#  358,
#  389,
#  302,
#  282,
#  297,
#  322,
#  289,
#  282,
#  393,
#  391,
#  220,
#  400,
#  244,
#  329,
#  248,
#  254,
#  268,
#  377,
#  326,
#  375,
#  358,
#  387,
#  394,
#  409,
#  319,
#  405,
#  319,
#  361,
#  416,
#  239,
#  372,
#  314,
#  377,
#  405,
#  375,
#  316,
#  345,
#  361,
#  286,
#  346,
#  265,
#  389,
#  269,
#  374,
#  412,
#  221,
#  249,
#  346,
#  311,
#  328,
#  345,
#  319,
#  368,
#  395,
#  360,
#  432,
#  283,
#  388,
#  199,
#  350,
#  277,
#  406,
#  333,
#  194,
#  404,
#  261,
#  400,
#  423,
#  364,
#  374,
#  292,
#  398,
# ...
